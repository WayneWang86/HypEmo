# %%
# !pip install spellchecker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 36.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for spellchecker: filename=spellchecker-0.4-py3-none-any.whl size=3966498 sha256=8578ab2653f7d5dbc68bfc279657a8d749d4e8157980ed2b36ab3acedb0653aa
#   Stored in directory: /root/.cache/pip/wheels/6c/90/c3/eac248d8755b2a7343487a2087b4b29ad98f388c3c8c69c286
# ...
#   Created wheel for inexactsearch: filename=inexactsearch-1.0.2-py3-none-any.whl size=7122 sha256=887a26eb1ead26aa31cda132407e4928a46182dbddc35a0484a079b44d411f8f
#   Stored in directory: /root/.cache/pip/wheels/63/19/2c/5e9f447f2533d457a1167c3e553f235e232b8a639e3f5fafab
# ...
#   Created wheel for silpa_common: filename=silpa_common-0.3-py3-none-any.whl size=8465 sha256=b4e9ba6c1f805fad76aad6b3789d2265229ef79e1ba1327e8ddb85b2a4416765
# ...

# %%
import pandas as pd

# Set the number of rows to display
pd.set_option('display.max_rows', 100)  # Change 100 to your desired number of rows

# Set the column width to ensure that the full text content is displayed
pd.set_option('display.max_colwidth', None)

# %%
import pandas as pd

## noise_aug high performance: relief， nervousness
## gpt_aug high performance:
noise_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/noise_augmentation.csv')
gpt_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/gpt_augmentation.csv')
roberta_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/word2_augmentation.csv')
emoji_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/emoji_augmentation.csv')
back_translation = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/train_back_translation.csv')
train_data = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/train_basline.csv')

# %%
back_translation[back_translation['text'] != train_data['text']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-57ec4ee316cb> in <cell line: 1>()
# ----> 1 back_translation[back_translation['text'] != train_data['text']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __ne__(self, other)
#      44     @unpack_zerodim_and_defer("__ne__")
#      45     def __ne__(self, other):
# ---> 46         return self._cmp_method(other, operator.ne)
#      47
#      48     @unpack_zerodim_and_defer("__lt__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6235
# ...

# %%
from spellchecker import SpellChecker
import pandas as pd

# Example DataFrame
data = {'text': ['This is a smaple text', 'Another txt with mispelled words', 'Perfectly spelled text']}
df = pd.DataFrame(data)

def count_misspelled_words(text):
    spell = SpellChecker()
    words = text.split()
    misspelled = spell.unknown(words)
    return len(misspelled)

df['misspelled_count'] = df['text'].apply(count_misspelled_words)

print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-30e1deca3a89> in <cell line: 1>()
# ----> 1 from spellchecker import SpellChecker
#       2 import pandas as pd
#       3
#       4 # Example DataFrame
#       5 data = {'text': ['This is a smaple text', 'Another txt with mispelled words', 'Perfectly spelled text']}
#
# ModuleNotFoundError: No module named 'spellchecker'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
label2idx = {'admiration': 0, 'amusement': 1, 'anger': 2,
      'annoyance': 3, 'approval': 4, 'caring': 5,
      'confusion': 6, 'curiosity': 7, 'desire': 8,
      'disappointment': 9, 'disapproval': 10, 'disgust': 11,
      'embarrassment': 12, 'excitement': 13, 'fear': 14,
      'gratitude': 15, 'grief': 16, 'joy': 17,
      'love': 18, 'nervousness': 19, 'optimism': 20,
      'pride': 21, 'realization': 22, 'relief': 23,
      'remorse': 24, 'sadness': 25, 'surprise': 26}
idx2label = {}
for key, val in label2idx.items():
  idx2label[val] = key

# %%
train_data['true_label'] = train_data['label'].replace(idx2label)

# %%
noise_aug[noise_aug['true_label'] == 'relief']
# Out:
#                                                    text  \
# 26    glad you feel better! my offer still stands th...
# 240                         no one cimes here it’s cool
# 302   i’m glad you fixed mihnesota, because there is...
# 335   oh man, glad i'm not watching this with my ext...
# 346                       thwt's a welcome relief. lol.
# ...                                                 ...
# 8283  i’m glad gou’re safe now and nothing bad happe...
# 8287  wow.... so many people here apparently don't k...
# 8333  oh kk cool so i don't feel baf at all about it...
# 8460  at least this makes me f1el bwtter about not b...
# 8549                               whew. i'm safe th3n.
#
#                                                aug_text  label true_label
# 26                            i'm glad you feel better!     23     relief
# 240                                               cool.     23     relief
# ...

# %%
train_data[train_data['true_label'] == 'relief']
# Out:
#                                                     text  \
# 66     glad you feel better! my offer still stands th...
# 647                          no one comes here it’s cool
# 805    i’m glad you fixed minnesota, because there is...
# 882    oh man, glad i'm not watching this with my ext...
# 939                        that's a welcome relief. lol.
# ...                                                  ...
# 22394  i’m glad you’re safe now and nothing bad happe...
# 22399  wow.... so many people here apparently don't k...
# 22529  oh ok cool so i don't feel bad at all about it...
# 22859  at least this makes me feel better about not b...
# 23083                               whew. i'm safe then.
#
#                                                 aug_text  label true_label
# 66                             i'm glad you feel better!     23     relief
# 647                                                cool.     23     relief
# ...

# %%
from textblob import TextBlob

# %%
gpt_aug[gpt_aug['true_label'] == 'disapproval'].loc[4897, 'text']
# Out:
# "that's far more costly than, you know, recycling it..."

# %%
gpt_aug[gpt_aug['true_label'] == 'disapproval'].loc[4897, 'aug_text']
# Out:
# "that's much more expensive to recover than, you know..."

# %%
roberta_aug[roberta_aug['true_label'] == 'disapproval' && roberta_aug['true_label'] == 'that's much more expensive to recover than, you know...'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4897
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
gpt_aug
# Out:
#                                                                                                                                              text  \
# 0                                                                                                                   unclean southern masturbators
# 1                                                                            demographics? i don't know anyone under 35 who has cable television.
# 2                             r/sleeptrain might be time for some slumber coaching. take a look and try to sense what's suitable for your family.
# 3                                                                  [name] - same bloody problem, slightly better control of the english language.
# 4                                                   all sounds feasible except the key, i can't see how it was overlooked in the initial search.
# ...

# %%
roberta_aug[roberta_aug['true_label'] == 'disapproval'].loc[8671, 'text']
# Out:
# '[name] was half-blood but it is the smart idea not switch up half race.'

# %%
train_data[train_data['true_label'] == 'disapproval'].loc[23477, 'text']
# Out:
# "[name] was half-blood but it wasn't a smart idea to bring up his father."

# %%
gpt_aug[gpt_aug['true_label'] == 'desire'].head(100)
# Out:
#                                                                                                                                                    text  \
# 46                                                                                                     really wish we had obtained something like this!
# 69                                                                                        Currency always speak. I want more to learn from this lesson.
# 95                                                                                                                I want to give [name] a mosquito bite
# 98                                                                                                          I wish my mother was catgirl knowledgeable.
# 114                               > i want to feel peace and not have to wake up everyday anxious for what the day has in store. i can connect to this.
# ...

# %%
train_data[(train_data['aug_text'] == "let's hope this book isn't too popular, it'll damage their profits." )]
# Out:
#                                                                                                                                                 text  \
# 23473  it is. i bet chantex and all the other 'quit smoking' companies hope this book doesn't become too popular. that would cut into their profits.
#
#                                                                   aug_text  \
# 23473  let's hope this book isn't too popular, it'll damage their profits.
#
#        label   true_label
# 23473     10  disapproval

# %%
roberta_aug[roberta_aug['aug_text'] == 'i really want pizza right now.']
# Out:
#                              text                        aug_text  label  \
# 3160  i might want pizza more now  i really want pizza right now.      8
#
#      true_label
# 3160     desire

# %%
roberta_aug[roberta_aug['aug_text'] == 'i really want pizza right now.']

# %%
roberta_aug[roberta_aug['true_label'] == 'annoyance']
# Out:
#                                                                                                                                                            text  \
# 0                                                                                                                                              dirty blond chef
# 3                                                                                 [name] : same same problem, new simplified command into the english language.
# 10                                                                                                           the Democrats are anti military. you make a idiot.
# 17                                                        seriously stupid. You want to see how this second hand went into detail. this was the one soulread in
# 21                                                                                                             three points, five jokes. but. very. seriously."
# ...

# %%
train_data[train_data['aug_text'] == '"man, stop, seriously."']
# Out:
#                                                    text  \
# 54  three words, no subtlety. "dude. stop. seriously."
#
#                    aug_text  label true_label
# 54  "man, stop, seriously."      3  annoyance
