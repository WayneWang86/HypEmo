# %%
import pandas as pd
from sklearn.metrics import f1_score, recall_score, precision_score, precision_recall_fscore_support

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
noise_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/noise_aug/test_pred_best_f1.csv')
back_trans = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/back_trans/test_pred_best_f1.csv')
emo_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/emo_to_text/test_pred_best_f1.csv')
baseline = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/baseline/test_pred_best_f1.csv')
gpt_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/gpt_aug/test_pred_best_f1.csv')
multi_label = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/gpt_aug/test_pred_best_f1.csv')
test_data = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/Test pred/test.csv')

# %%
emoji_aug = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/pred_output/ensemble/test_pred_best_f1.csv')
test_data = pd.read_csv('/content/drive/MyDrive/11777-advNLP-group-shared-drive/HW4/Test pred/ground_truth.csv')

# %%
output = pd.concat([test_data[['text', 'aug_text', 'label']], emoji_aug[['Predicted_Label']]], axis=1)

# Reset the index if needed
output.reset_index(drop=True, inplace=True)

# %%
output.head()
# Out:
#                                                 text  \
# 0  i’m really sorry about your situation :( altho...
# 1    it's wonderful because it's awful. at not with.
# 2  kings fan here, good luck to you guys! will be...
# 3  i didn't know that, thank you for teaching me ...
# 4  thank you for asking questions and recognizing...
#
#                                             aug_text  label  Predicted_Label
# 0  i'm very sorry about your situation, though i ...     25               24
# 1                 it's wonderful because it's scary.      0                0
# 2                            good luck, king's fans!     13               20
# 3  i don't know, thanks for teaching me something...     15               15
# 4  and i admit that there are things you may not ...     15               15

# %%
label2idx = {'admiration': 0, 'amusement': 1, 'anger': 2,
      'annoyance': 3, 'approval': 4, 'caring': 5,
      'confusion': 6, 'curiosity': 7, 'desire': 8,
      'disappointment': 9, 'disapproval': 10, 'disgust': 11,
      'embarrassment': 12, 'excitement': 13, 'fear': 14,
      'gratitude': 15, 'grief': 16, 'joy': 17,
      'love': 18, 'nervousness': 19, 'optimism': 20,
      'pride': 21, 'realization': 22, 'relief': 23,
      'remorse': 24, 'sadness': 25, 'surprise': 26}
idx2label = {}
for key, val in label2idx.items():
  idx2label[val] = key
output['predict_label'] = output['Predicted_Label'].replace(idx2label)
output['true_label'] = output['label'].replace(idx2label)

# %%
## geneate stat for all labels
true_labels = (output['label']).astype(int)
predicted_labels = (output['Predicted_Label']).astype(int)

precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predicted_labels, average='weighted')
print("f1 score is ", f1 )
print("recall is ", recall )
print("precision is ", precision )
# Out:
# f1 score is  0.6445703406286377
# recall is  0.6514745308310992
# precision is  0.6461342059908141
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## geneate stat for aug labels
aug_output = output[output['true_label'].isin(['annoyance', 'approval', 'caring', 'confusion', 'desire', 'disappointment', 'disapproval', 'excitement', 'nervousness', 'grief', 'pride', 'realization', 'relief'])]
true_labels = (aug_output['label']).astype(int)
predicted_labels = (aug_output['Predicted_Label']).astype(int)

precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predicted_labels, average='weighted')
print("f1 score is ", f1 )
print("recall is ", recall )
print("precision is ", precision )
# Out:
# f1 score is  0.5404903192313426
# recall is  0.47513321492007105
# precision is  0.6513365344528056
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## geneate stat for unaug labels
non_aug_output = output[~output['true_label'].isin(['annoyance', 'approval', 'caring', 'confusion', 'desire', 'disappointment', 'disapproval', 'excitement', 'nervousness', 'grief', 'pride', 'realization', 'relief'])]
true_labels = (non_aug_output['label']).astype(int)
predicted_labels = (non_aug_output['Predicted_Label']).astype(int)

precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predicted_labels, average='weighted')
print("f1 score is ", f1 )
print("recall is ", recall )
print("precision is ", precision )
# Out:
# f1 score is  0.8040328787420239
# recall is  0.7583423035522067
# precision is  0.8675025363746354
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
group2label = {
"positive": ["amusement", "excitement", "joy", "love", "desire", "optimism", "caring", "pride", "admiration", "gratitude", "relief", "approval"],
"negative": ["fear", "nervousness", "remorse", "embarrassment", "disappointment", "sadness", "grief", "disgust", "anger", "annoyance", "disapproval"],
"ambiguous": ["realization", "surprise", "curiosity", "confusion"]
}
label2group = {}
for key, vals in group2label.items():
  for val in vals:
    label2group[val] = key
output['predict_group'] = output['predict_label'].replace(label2group)
output['true_group'] = output['true_label'].replace(label2group)

# %%
output.head()
# Out:
#                                                 text  \
# 0  i’m really sorry about your situation :( altho...
# 1    it's wonderful because it's awful. at not with.
# 2  kings fan here, good luck to you guys! will be...
# 3  i didn't know that, thank you for teaching me ...
# 4  thank you for asking questions and recognizing...
#
#                                             aug_text  label  Predicted_Label  \
# 0  i'm very sorry about your situation, though i ...     25               24
# 1                 it's wonderful because it's scary.      0                0
# 2                            good luck, king's fans!     13               20
# 3  i don't know, thanks for teaching me something...     15               15
# 4  and i admit that there are things you may not ...     15               15
#
#   predict_label  true_label predict_group true_group
# 0       remorse     sadness      negative   negative
# 1    admiration  admiration      positive   positive
# ...

# %%
labels = group2label.keys()  # Get unique labels

f1_scores = []
recall_scores = []
precision_scores = []

for label in labels:
  true_labels = (output['true_group'] == label).astype(int)
  predicted_labels = (output['predict_group'] == label).astype(int)

  f1 = f1_score(true_labels, predicted_labels)
  recall = recall_score(true_labels, predicted_labels)
  precision = precision_score(true_labels, predicted_labels)

  f1_scores.append(f1)
  recall_scores.append(recall)
  precision_scores.append(precision)

# %%
result_df = pd.DataFrame({'Label': labels, 'F1_Score': f1_scores, 'Recall': recall_scores, 'Precision': precision_scores})
result_df
# Out:
#        Label  F1_Score    Recall  Precision
# 0   positive  0.911665  0.923893   0.899757
# 1   negative  0.840959  0.828326   0.853982
# 2  ambiguous  0.729332  0.717149   0.741935

# %%
len(['annoyance', 'approval', 'caring', 'confusion', 'desire', 'disappointment', 'disapproval', 'excitement', 'nervousness', 'grief', 'pride', 'realization', 'relief'])
# Out:
# 13
