# %%
# !git clone https://github.com/hapy-ditto/HypEmo.git
# Out:
# Cloning into 'HypEmo'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 106 (delta 4), reused 1 (delta 0), pack-reused 96
# Receiving objects: 100% (106/106), 3.14 MiB | 22.67 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
import pandas as pd
output = pd.read_csv('/content/HypEmo/output.csv')

# %%
test_data = pd.read_csv('/content/HypEmo/data/go_emotion/test.csv')

# %%
test_data.head()
# Out:
#                                                 text  \
# 0  i’m really sorry about your situation :( altho...
# 1    it's wonderful because it's awful. at not with.
# 2  kings fan here, good luck to you guys! will be...
# 3  i didn't know that, thank you for teaching me ...
# 4  thank you for asking questions and recognizing...
#
#                                             aug_text  label
# 0  i'm very sorry about your situation, though i ...     25
# 1                 it's wonderful because it's scary.      0
# 2                            good luck, king's fans!     13
# 3  i don't know, thanks for teaching me something...     15
# 4  and i admit that there are things you may not ...     15

# %%
test_data.shape
# Out:
# (2984, 3)

# %%
output.shape
# Out:
# (2984, 2)

# %%
output = pd.concat([test_data[['text', 'aug_text']], output], axis=1)

# Reset the index if needed
output.reset_index(drop=True, inplace=True)

# %%
output.head()
# Out:
#                                                 text  \
# 0  i’m really sorry about your situation :( altho...
# 1    it's wonderful because it's awful. at not with.
# 2  kings fan here, good luck to you guys! will be...
# 3  i didn't know that, thank you for teaching me ...
# 4  thank you for asking questions and recognizing...
#
#                                             aug_text  predict  output
# 0  i'm very sorry about your situation, though i ...       24      25
# 1                 it's wonderful because it's scary.        0       0
# 2                            good luck, king's fans!       13      13
# 3  i don't know, thanks for teaching me something...       15      15
# 4  and i admit that there are things you may not ...       15      15

# %% [markdown]
# ## Error Analysis

# %%
output.columns
# Out:
# Index(['text', 'aug_text', 'predict', 'output'], dtype='object')

# %%
output.to_csv('hypmo_output_analysis.csv')

# %%
label2idx = {'admiration': 0, 'amusement': 1, 'anger': 2,
      'annoyance': 3, 'approval': 4, 'caring': 5,
      'confusion': 6, 'curiosity': 7, 'desire': 8,
      'disappointment': 9, 'disapproval': 10, 'disgust': 11,
      'embarrassment': 12, 'excitement': 13, 'fear': 14,
      'gratitude': 15, 'grief': 16, 'joy': 17,
      'love': 18, 'nervousness': 19, 'optimism': 20,
      'pride': 21, 'realization': 22, 'relief': 23,
      'remorse': 24, 'sadness': 25, 'surprise': 26}
idx2label = {}
for key, val in label2idx.items():
  idx2label[val] = key
output['predict_label'] = output['predict'].replace(idx2label)
output['true_label'] = output['output'].replace(idx2label)

# %% [markdown]
# ### Analyze Using Goemotions Taxonomy

# %%
from sklearn.metrics import f1_score, recall_score
labels = label2idx.keys()  # Get unique labels

f1_scores = []
recall_scores = []

for label in labels:
  true_labels = (output['true_label'] == label).astype(int)
  predicted_labels = (output['predict_label'] == label).astype(int)

  f1 = f1_score(true_labels, predicted_labels)
  recall = recall_score(true_labels, predicted_labels)

  f1_scores.append(f1)
  recall_scores.append(recall)

# %%
output[output['true_label'] == 'grief']
# Out:
#                                                    text  \
# 419   [name] death is just so..... senseless. why? w...
# 1676                             rip the guy from psych
#
#                            aug_text  predict  output predict_label true_label
# 419                     why why why        6      16     confusion      grief
# 1676  rip that guy out of his mind.        2      16         anger      grief

# %%
result_df = pd.DataFrame({'Label': labels, 'F1_Score': f1_scores, 'Recall': recall_scores})

# %%
result_df
# Out:
#              Label  F1_Score    Recall
# 0       admiration  0.732782  0.764368
# 1        amusement  0.833787  0.822581
# 2            anger  0.514768  0.465649
# 3        annoyance  0.354312  0.391753
# 4         approval  0.470588  0.440678
# 5           caring  0.477778  0.500000
# 6        confusion  0.392523  0.432990
# 7        curiosity  0.640212  0.687500
# 8           desire  0.465116  0.357143
# 9   disappointment  0.359551  0.363636
# 10     disapproval  0.481375  0.430769
# 11         disgust  0.536232  0.486842
# 12   embarrassment  0.521739  0.521739
# 13      excitement  0.481203  0.561404
# 14            fear  0.796748  0.753846
# 15       gratitude  0.897881  0.896154
# 16           grief  0.000000  0.000000
# 17             joy  0.549223  0.569892
# 18            love  0.844037  0.862500
# 19     nervousness  0.413793  0.500000
# 20        optimism  0.585635  0.495327
# 21           pride  0.285714  0.285714
# 22     realization  0.275862  0.314607
# 23          relief  0.200000  0.142857
# 24         remorse  0.659091  0.659091
# 25         sadness  0.632075  0.656863
# 26        surprise  0.539877  0.505747

# %%
output[output['predict_label'] == 'pride']
# Out:
#                                                    text  \
# 89                                        proud of you.
# 396       i'm flattered but i'm a good [religion] scarf
# 1011  eh, says who? anyway, i like being by myself. ...
# 2563              boy what an accomplishment, so proud!
# 2703   too damn often!! and i’m cute as hell! i’m mad!!
# 2884  i am proud to be racist no one in real life wi...
# 2906  i have more faith in [name] than anyone on the...
#
#                                                aug_text  predict  output  \
# 89                                    i'm proud of you.       21       0
# 396                i'm flattered, but i'm a good scarf.       21       0
# 1011         anyway, i like being alone. i'm alone now.       21       7
# 2563                boy, what an achievement, so proud!       21      21
# 2703                                       i'm so cute!       21       3
# 2884  i'm proud to be a racist, and no one in real l...       21      21
# 2906  i believe in three strange worlds more than an...       21      20
#
#      predict_label  true_label
# 89           pride  admiration
# 396          pride  admiration
# 1011         pride   curiosity
# 2563         pride       pride
# 2703         pride   annoyance
# 2884         pride       pride
# 2906         pride    optimism

# %% [markdown]
# ### Analyze Using Ekman's Grouping Method

# %%
senti2label = {
"anger": ["anger", "annoyance", "disapproval"],
"disgust": ["disgust"],
"fear": ["fear", "nervousness"],
"joy": ["joy", "amusement", "approval", "excitement", "gratitude",  "love", "optimism", "relief", "pride", "admiration", "desire", "caring"],
"sadness": ["sadness", "disappointment", "embarrassment", "grief",  "remorse"],
"surprise": ["surprise", "realization", "confusion", "curiosity"]
}
label2senti = {}
for key, vals in senti2label.items():
  for val in vals:
    label2senti[val] = key

output['predict_senti'] = output['predict_label'].replace(label2senti)
output['true_senti'] = output['true_label'].replace(label2senti)

# %%
labels = senti2label.keys()  # Get unique labels

f1_scores = []
recall_scores = []

for label in labels:
  true_labels = (output['true_senti'] == label).astype(int)
  predicted_labels = (output['predict_senti'] == label).astype(int)

  f1 = f1_score(true_labels, predicted_labels)
  recall = recall_score(true_labels, predicted_labels)

  f1_scores.append(f1)
  recall_scores.append(recall)

# %%
result_df = pd.DataFrame({'Label': labels, 'F1_Score': f1_scores, 'Recall': recall_scores})
result_df
# Out:
#       Label  F1_Score    Recall
# 0     anger  0.654187  0.638462
# 1   disgust  0.536232  0.486842
# 2      fear  0.750000  0.740260
# 3       joy  0.883575  0.875858
# 4   sadness  0.660342  0.671815
# 5  surprise  0.665971  0.710468

# %% [markdown]
# ## Analyze Using Sentiment Taxomony

# %%
group2label = {
"positive": ["amusement", "excitement", "joy", "love", "desire", "optimism", "caring", "pride", "admiration", "gratitude", "relief", "approval"],
"negative": ["fear", "nervousness", "remorse", "embarrassment", "disappointment", "sadness", "grief", "disgust", "anger", "annoyance", "disapproval"],
"ambiguous": ["realization", "surprise", "curiosity", "confusion"]
}

# %%
label2group = {}
for key, vals in group2label.items():
  for val in vals:
    label2group[val] = key

# %%
output['predict_group'] = output['predict_label'].replace(label2group)
output['true_group'] = output['true_label'].replace(label2group)

# %%
labels = group2label.keys()  # Get unique labels

f1_scores = []
recall_scores = []

for label in labels:
  true_labels = (output['true_group'] == label).astype(int)
  predicted_labels = (output['predict_group'] == label).astype(int)

  f1 = f1_score(true_labels, predicted_labels)
  recall = recall_score(true_labels, predicted_labels)

  f1_scores.append(f1)
  recall_scores.append(recall)

# %%
result_df = pd.DataFrame({'Label': labels, 'F1_Score': f1_scores, 'Recall': recall_scores})
result_df
# Out:
#        Label  F1_Score    Recall
# 0   positive  0.883575  0.875858
# 1   negative  0.796943  0.783262
# 2  ambiguous  0.665971  0.710468

# %% [markdown]
# ### Analyze the correlation between training data size and F1-score

# %%
train_data = pd.read_csv('/content/HypEmo/data/go_emotion/train.csv')
train_data['true_label'] = train_data['label'].replace(idx2label)
train_goe_label = train_data.groupby('true_label').size().to_frame(name='counts').reset_index()

# %%
train_data[train_data['true_label'] == 'admiration']
# Out:
#                                                     text  \
# 5      damn youtube and outrage drama is super lucrat...
# 18                            famous for his 3-4 defense
# 28     twilight... still a better love story than the...
# 30                                what a wonderful world
# 44                      you just make her sound awesome.
# ...                                                  ...
# 23447  kirkland liquor is amazing. i can get a cheap ...
# 23468           wow nice way to live in an echo chamber.
# 23470         even when it's bad, it's still pretty good
# 23471  this is my favorite reddit conversation i’ve s...
# 23474  even though i didn't know you personally, but ...
#
#                                                 aug_text  label  true_label
# 5      and the angry play is a super-profit re-examin...      0  admiration
# 18                      he's famous for his 3-4 defense.      0  admiration
# 28     dawn... is still a better love story than the ...      0  admiration
# 30                               what a wonderful world.      0  admiration
# 44                      you just make her sound awesome.      0  admiration
# ...                                                  ...    ...         ...
# 23447  i could buy a cheap bottle of vodka or scotch,...      0  admiration
# 23468   wow. that's a good way to live in the echo room.      0  admiration
# 23470                    even if it's bad, it's not bad.      0  admiration
# 23471         this is my favorite redacted conversation.      0  admiration
# 23474  i don't know you personally, but i just want t...      0  admiration
#
# [2710 rows x 4 columns]

# %%
labels = label2idx.keys()
f1_scores = []
recall_scores = []

for label in labels:
  true_labels = (output['true_label'] == label).astype(int)
  predicted_labels = (output['predict_label'] == label).astype(int)

  f1 = f1_score(true_labels, predicted_labels)
  recall = recall_score(true_labels, predicted_labels)

  f1_scores.append(f1)
  recall_scores.append(recall)
result_df = pd.DataFrame({'Label': labels, 'F1_Score': f1_scores, 'Recall': recall_scores})

# %%
result = pd.merge(train_goe_label, result_df, left_on='true_label', right_on='Label')

# %%
result
# Out:
#         true_label  counts           Label  F1_Score    Recall
# 0       admiration    2710      admiration  0.732782  0.764368
# 1        amusement    1652       amusement  0.833787  0.822581
# 2            anger    1025           anger  0.514768  0.465649
# 3        annoyance    1451       annoyance  0.354312  0.391753
# 4         approval    1873        approval  0.470588  0.440678
# 5           caring     649          caring  0.477778  0.500000
# 6        confusion     858       confusion  0.392523  0.432990
# 7        curiosity    1389       curiosity  0.640212  0.687500
# 8           desire     389          desire  0.465116  0.357143
# 9   disappointment     709  disappointment  0.359551  0.363636
# 10     disapproval    1402     disapproval  0.481375  0.430769
# 11         disgust     498         disgust  0.536232  0.486842
# 12   embarrassment     203   embarrassment  0.521739  0.521739
# 13      excitement     510      excitement  0.481203  0.561404
# 14            fear     430            fear  0.796748  0.753846
# 15       gratitude    1857       gratitude  0.897881  0.896154
# 16           grief      39           grief  0.000000  0.000000
# 17             joy     853             joy  0.549223  0.569892
# 18            love    1427            love  0.844037  0.862500
# 19     nervousness      85     nervousness  0.413793  0.500000
# 20        optimism     861        optimism  0.585635  0.495327
# 21           pride      51           pride  0.285714  0.285714
# 22     realization     586     realization  0.275862  0.314607
# 23          relief      88          relief  0.200000  0.142857
# 24         remorse     353         remorse  0.659091  0.659091
# 25         sadness     817         sadness  0.632075  0.656863
# 26        surprise     720        surprise  0.539877  0.505747
